# %%
import skimage.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install nibabel
# Out:
# ...
#      |████████████████████████████████| 3.3 MB 1.5 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/ashwani/anaconda3/envs/ai-summer/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import nibabel as nib

# %%
img_2d = sio.imread("testimg_2d_flair.png")

# %%
img_2d.shape
# Out:
# (342, 726, 3)

# %%
type(img_2d)
# Out:
# numpy.ndarray

# %%
plt.imshow(img_2d)

# %%
img_3d_t2 = np.array(nib.load("testimg_3d_t2.nii").get_fdata().astype(np.float32))

# %%
img_3d_t2.shape
# Out:
# (240, 240, 155)

# %%
type(img_3d_t2)
# Out:
# numpy.ndarray

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
data = np.random.random(size=(3, 3, 3))
z, x, y = img_3d.nonzero()
ax.scatter(x, y, z, c=z, alpha=1)
plt.show()

# %%
img_3d_seg = np.array(nib.load("testimg_3d_seg.nii").get_fdata().astype(np.float32))

# %%
img_3d_seg.shape
# Out:
# (240, 240, 155)

# %%
plt.imshow(img_3d_seg[:,:,70])

# %%
np.count_nonzero(img_3d_seg[:,:,70]) > 0
# Out:
# True

# %%
res = []
for i in range(1,155):
    img = img_3d_seg[:,:,i]
    if(np.count_nonzero(img) > 100):
        #print("Slice:", i, " has ", np.count_nonzero(img), " nonzero pixels.")
        res.append(i)

# %%
len(res)
# Out:
# 78

# %%
plt.imshow(img_3d_seg[:,:,29])

# %%
img_sliced = img_3d_t2[:,:,res]

# %%
img_sliced.shape
# Out:
# (240, 240, 78)

# %%
num = 50
plt.imshow(np.hstack((img_sliced[:,:,num], img_3d_seg[:,:,num])))

# %%
plt.imshow(img_sliced[:,:,num])

# %%
plt.imshow(img_3d_seg[:,:,num])

# %%
img_sliced[:,:,num].max()
# Out:
# 312.0

# %%
img_3d[:,:,num].min()
# Out:
# 0.0
